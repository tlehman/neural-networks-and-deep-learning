# %% [markdown]
# # Loading up the MNIST dataset

# %%
import mnist_loader
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()

# %% [markdown]
# ## Peeking at the MNIST training data

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
img0 = training_data[0][0].reshape(28,28)

def peekimg(img):
    plt.imshow(img)

def testshow(index):
    im = test_data[index][0]
    peekimg(im.reshape(28,28))
    return im

# %%
im4 = testshow(4)
im7 = testshow(0)
im2 = testshow(1)
im1 = testshow(2)

# %% [markdown]
# # Loading the neural network code
#
# Initialize it so input layer is $28x28 = 784$, 30 hidden neurons and 10 output neurons, to represent the ten digits it will be trained to recognize.

# %%
import network
net = network.Network([784, 30, 10])

# %% [markdown]
# # Use stochastic gradient descent to train the network
#
# Using learning rate $\eta = 30$, over 30 epochs.

# %%
net.SGD(training_data, 30, 10, 3.0, test_data=test_data)
# Out:
# Epoch 0: 8967 / 10000
# Epoch 1: 9207 / 10000
# Epoch 2: 9296 / 10000
# Epoch 3: 9349 / 10000
# Epoch 4: 9368 / 10000
# Epoch 5: 9353 / 10000
# Epoch 6: 9418 / 10000
# Epoch 7: 9398 / 10000
# Epoch 8: 9423 / 10000
# Epoch 9: 9382 / 10000
# Epoch 10: 9438 / 10000
# Epoch 11: 9454 / 10000
# Epoch 12: 9436 / 10000
# Epoch 13: 9452 / 10000
# Epoch 14: 9459 / 10000
# Epoch 15: 9444 / 10000
# Epoch 16: 9421 / 10000
# Epoch 17: 9445 / 10000
# Epoch 18: 9457 / 10000
# Epoch 19: 9452 / 10000
# Epoch 20: 9479 / 10000
# Epoch 21: 9454 / 10000
# Epoch 22: 9465 / 10000
# Epoch 23: 9450 / 10000
# Epoch 24: 9457 / 10000
# Epoch 25: 9454 / 10000
# Epoch 26: 9450 / 10000
# Epoch 27: 9457 / 10000
# Epoch 28: 9478 / 10000
# Epoch 29: 9482 / 10000

# %%
def recognize(im):
    output = net.feedforward(im).reshape(1,10)
    return np.argmax(output)

# %%
recognize(im1)
# Out:
# 1

# %%
def showoff(index):
    peekimg(test_data[index][0].reshape(28,28))
    print recognize(test_data[index][0])

# %%
showoff(10)
# Out:
# 0

# %%
import Image from PIL
import matplotlib.image as mpimg
Image.open("/Users/tlehman/Desktop/1.png").convert('LA')
# Out:
#   File "<ipython-input-117-83288c0a0bea>", line 1
#     import Image from PIL
#                     ^
# SyntaxError: invalid syntax

# %%
recognize(handwritten4.reshape((28*28, 1)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-0a5f7e2ae3f9> in <module>()
# ----> 1 recognize(handwritten4.reshape((28*28, 1)))
#
# /usr/local/lib/python2.7/site-packages/PIL/Image.pyc in __getattr__(self, name)
#     608             new['data'] = self.tobytes()
#     609             return new
# --> 610         raise AttributeError(name)
#     611
#     612     def __getstate__(self):
#
# AttributeError: reshape
